# %%
# !pip install -q groq
# !pip install -q llama-index-llms-groq
# !pip install -q llama-parse
# !pip install -q llama-index-embeddings-huggingface
# !pip install -q sentence-transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 146.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 155.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.6/142.6 kB 18.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# torch 2.11.0+cu128 requires setuptools<82, but you have setuptools 82.0.1 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.0/362.0 kB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.

# %%
import os

os.environ["LLAMA_CLOUD_API_KEY"] =
os.environ["GROQ_API_KEY"] =

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from llama_index.llms.groq import Groq
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings
import os

llm = Groq(
    model="llama-3.1-8b-instant",
    api_key=os.environ["GROQ_API_KEY"],
    temperature=0,
)
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

Settings.llm = llm
Settings.embed_model = embed_model

print("Groq (Llama 3.3 70B) + HuggingFace embeddings configured")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Groq (Llama 3.3 70B) + HuggingFace embeddings configured

# %%
from google.colab import drive
drive.mount('/content/drive')

from pathlib import Path

drive_pdf_dir = "/content/drive/MyDrive/KnowledgeBase"
papers = [str(p) for p in Path(drive_pdf_dir).glob("*.pdf")]

print(f"Found {len(papers)} PDFs:")
for p in papers:
    print(f"  - {Path(p).name}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 59 PDFs:
#   - Australian Youth Mental Health and Climate Change Concern After the Black Summer Bushfires.pdf
#   - Disaster preparedness and community helping behaviour in the wake of the 2020 Oregon wildfires.pdf
#   - Integrated fire management as an adaptation and mitigation strategy to altered fire regimes.pdf
#   - Public Health Messaging for Wildfire Smoke Cast a Wide Net.pdf
#   - Reimagine fire science for the anthropocene.pdf
#   - Bushfire Smoke and Children's Health-Exploring a Communication Gap.pdf
#   - Social group connections support mental health following wildfire.pdf
#   - Efficacy of Communication Techniques and Health Outcomes of Bushfire Smoke Exposure- A Scoping Review.pdf
#   - Wildfire smoke and health impacts- a narrative review.pdf
#   - California and Oregon NICU Wildfire Disaster Preparedness Tools.pdf
#   - Eco-Anxiety and Mental Health Correlates of Climate Change Distress.pdf
#   - A Systematic Review of the Impacts of Climate Change on Critical Infrastructure in Canada.pdf
#   - Child-focused climate change and health content in medical schools and pediatric residencies.pdf
#   - Investigating the Health Impacts of Climate Change among People with Pre-Existing Mental Health Problems A Scoping Review.pdf
#   - Wildfires and Older Adults A Scoping Review of Impacts, Risks, and Interventions.pdf
#   - Wildfire, Environmental Risk and Deliberative Planning in the Locarnese Region of Switzerland..pdf
#   - A scoping review of wildfire smoke risk communications issues, gaps, and recommendations.pdf
#   - Wildfire Exposure and Respiratory Health- A Comprehensive Review of Emerging Evidence.pdf
#   - Heatwaves and wildfires suffocate our healthy start to life- time to assess impact and take action.pdf
#   - Public health applications of historical smoke forecasts- An evaluation of archived BlueSky data for the coterminous United States, 2015-2018.pdf
#   - Trends and Gaps in Climate Change and Health Research in the Republic of Korea.pdf
#   - Machine learning-enabled regional multi-hazards risk assessment considering social vulnerability.pdf
#   - Comprehensive Care for Wildfire Survivors in Los Angeles, 2025.pdf
#   - Stressors for farmworker parents during wildfire season.pdf
#   - Monitoring Public Health During the 2023 Maui Wildfire Using Google Search Trends.pdf
#   - Emergency Medical Services response to wildfires from a public health perspective- A systematic review.pdf
#   - Effects of Wildfire Events on California Radiation Oncology Clinics and Patients.pdf
#   - Assessment of Regional Nursing Home Preparedness for and Regulatory Responsiveness to Wildfire Risk in the Western US.pdf
#   - GeoHealth - 2021 - Johnson - Uncertainty in Health Impact Assessments of Smoke From a Wildfire Event.pdf
#   - Health equity in the wake of disasters and extreme weather- evidence from an umbrella review.pdf
#   - Chronic Mental Health Sequelae of Climate Change Extremes A Case Study of the Deadliest Californian Wildfire.pdf
#   - Health Planning   Management - 2024 - Zurynski - Bolstering health systems to cope with the impacts of climate change.pdf
#   - Participatory multi-criteria evaluation of landscape values to inform wildfire management.pdf
#   - Role_of_Public_Health_in_Wildfire_Lessons_from_the.pdf
#   - Socio-demographic and health vulnerability in prescribed-burn exposed versus unexposed counties near the National Forest System.pdf
#   - Scaling Up- Citizen Science Engagement and Impacts Beyond the Individual.pdf
#   - münzel-et-al-2026-environmental-stressors-and-cardiovascular-health-acting-locally-for-global-impact-in-a-changing.pdf
#   - Responses to Wildfire and Prescribed Fire Smoke- A Survey of a Medically Vulnerable Adult Population in the Wildland-Urban Interface, Mariposa County, California..pdf
#   - Climate Change And Its Impact On Asthma In South Africa..pdf
#   - Engaging interested parties to optimize wildfire smoke communication in Canada challenges with initiating change.pdf
#   - Impact of Natural Disasters on Health Outcomes and Cancer Among Older Adults..pdf
#   - savich-et-al-2025-effects-of-wildfire-smoke-inhalation-on-respiratory-health.pdf
#   - Knowing Your Audience A Typology of Smoke Sense Participants to Inform Wildfire Smoke Health Risk Communication.pdf
#   - Quantifying the premature mortality and economic loss from wildfire-induced PM(2.5) in the contiguous U.S.pdf
#   - GeoHealth - 2019 - Rappold - Smoke Sense Initiative Leverages Citizen Science to Address the Growing Wildfire‐Related.pdf
#   - Combating converging crises- The role of universities in global health, climate, and equity.pdf
#   - Wildfire impacts on education and healthcare Paradise, California, after the Camp Fire.pdf
#   - Outbreak of Norovirus Illness Among Wildfire Evacuation Shelter Populations - Butte and Glenn Counties, California, November 2018.pdf
#   - Risk Analysis - 2026 - Bodas - Municipal Risk Communication and Public Trust  Reducing Counterproductive Behaviors Across.pdf
#   - The 2024 South America ablaze- health impacts and policy imperatives for protecting population health in an era of wildfires.pdf
#   - Changes in extreme events and the potential impacts on human health.pdf
#   - A Literature Review on the Impact of Wildfires on Emergency Departments- Enhancing Disaster Preparedness..pdf
#   - Housing Displacement, Employment Disruption, and Mental Health After the 2023 Maui Wildfires.pdf
#   - Improving Wildfire Readiness Among Patients With Chronic Obstructive Pulmonary Disease and Asthma- Applying a Population Health Approach to Climate Change.pdf
#   - An Ecological Perspective on Living with Fire in Ponderosa Pine Forests of Oregon and Washington- Resistance, Gone but not Forgotten.pdf
#   - Clearing the air- evaluating institutions' social media health messaging on wildfire and smoke risks in the US Pacific Northwest.pdf
#   - Who Among the Elderly Is Most Vulnerable to Exposure to and Health Risks of Fine Particulate Matter From Wildfire Smoke?.pdf
#   - Burning issues- trends in newspaper coverage of wildfire events and health..pdf
#   - Learning from Wildfire Disaster Experience in California NICUs.pdf

# %%
index_dir = "/content/drive/MyDrive/research_papers/index"

if Path(index_dir).exists():
    print("Saved index found — will load instead of re-parsing")
    use_saved = True
else:
    print("No saved index found — will parse all papers")
    use_saved = False
# Out:
# No saved index found — will parse all papers

# %%
import warnings
warnings.filterwarnings("ignore")

from llama_index.core import VectorStoreIndex, StorageContext, load_index_from_storage
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.schema import Document
from llama_parse import LlamaParse

if use_saved:
    # Load from Drive — no re-parsing needed
    print("Loading saved index from Drive...")
    storage_context = StorageContext.from_defaults(persist_dir=index_dir)
    combined_index = load_index_from_storage(storage_context)
    print("Index loaded successfully")

else:
    # Parse all papers and build index
    all_nodes = []

    for paper in papers:
        name = Path(paper).stem
        print(f"\nParsing: {name}")
        try:
            parser = LlamaParse(result_type="text")
            json_objs = parser.get_json_result(paper)
            json_list = json_objs[0]["pages"]
            docs = [
                Document(
                    text=page["text"],
                    metadata={"source": name, "page_label": page["page"]}
                )
                for page in json_list
            ]
            nodes = SentenceSplitter(chunk_size=1024).get_nodes_from_documents(docs)
            all_nodes.extend(nodes)
            print(f"Added {len(nodes)} chunks")
        except Exception as e:
            print(f"Skipping {name}: {e}")

    print(f"\nBuilding index over {len(all_nodes)} total chunks...")
    combined_index = VectorStoreIndex(all_nodes)

    # Save to Drive for future sessions
    print("Saving index to Drive...")
    combined_index.storage_context.persist(persist_dir=index_dir)
    print(f"Index saved to {index_dir}")
# Out:
# Parsing: Australian Youth Mental Health and Climate Change Concern After the Black Summer Bushfires
# Started parsing the file under job_id 4928b037-49de-4b29-b983-201edc3addc3
# Added 11 chunks
#
# Parsing: Disaster preparedness and community helping behaviour in the wake of the 2020 Oregon wildfires
# Started parsing the file under job_id 94f05e89-62f5-4119-88c1-bf2f454e153f
# .Added 42 chunks
#
# Parsing: Integrated fire management as an adaptation and mitigation strategy to altered fire regimes
# Started parsing the file under job_id 757db1f1-2416-4fcf-baec-fcca9962ddaa
# Added 30 chunks
#
# Parsing: Public Health Messaging for Wildfire Smoke Cast a Wide Net
# Started parsing the file under job_id 1e85438a-60f3-4918-bb84-a8b9115a3eca
# .Added 11 chunks
#
# Parsing: Reimagine fire science for the anthropocene
# Started parsing the file under job_id c13cb1ef-477e-443a-b12a-8ac51747e72f
# .Added 35 chunks
#
# Parsing: Bushfire Smoke and Children's Health-Exploring a Communication Gap
# Started parsing the file under job_id dacda948-bde9-4369-99dc-3b69c3c20cc1
# Added 17 chunks
#
# Parsing: Social group connections support mental health following wildfire
# Started parsing the file under job_id 68cfa4c7-9853-42c4-a8a2-193ee8461d5f
# .Added 24 chunks
#
# Parsing: Efficacy of Communication Techniques and Health Outcomes of Bushfire Smoke Exposure- A Scoping Review
# Started parsing the file under job_id 68c7f411-9c34-4f7f-8ba2-42f601ea2575
# .Added 22 chunks
#
# Parsing: Wildfire smoke and health impacts- a narrative review
# Started parsing the file under job_id 46863e61-8a1d-4a3f-a7b6-b8d0800893e0
# Added 18 chunks
#
# Parsing: California and Oregon NICU Wildfire Disaster Preparedness Tools
# Started parsing the file under job_id 45709b38-42d5-4587-a565-616eda14c8b8
# Added 15 chunks
#
# Parsing: Eco-Anxiety and Mental Health Correlates of Climate Change Distress
# Started parsing the file under job_id 02f5e25c-71a7-48b9-b275-291d2a125a40
# .Added 22 chunks
#
# Parsing: A Systematic Review of the Impacts of Climate Change on Critical Infrastructure in Canada
# Started parsing the file under job_id 11963ebe-3b25-4f63-aa22-f1f05c686049
# .Added 31 chunks
#
# Parsing: Child-focused climate change and health content in medical schools and pediatric residencies
# Started parsing the file under job_id b820f6de-bf75-4a06-bef5-c672c5b79ebb
# .Added 15 chunks
#
# Parsing: Investigating the Health Impacts of Climate Change among People with Pre-Existing Mental Health Problems A Scoping Review
# Started parsing the file under job_id 1f599386-80c9-4b3e-9b7b-ff96244ad72a
# .Added 44 chunks
#
# Parsing: Wildfires and Older Adults A Scoping Review of Impacts, Risks, and Interventions
# Started parsing the file under job_id 9bfb80d1-da90-4c5f-b9a9-27a7083bff86
# .Added 35 chunks
#
# Parsing: Wildfire, Environmental Risk and Deliberative Planning in the Locarnese Region of Switzerland.
# Started parsing the file under job_id 116cfdbf-95d8-4159-94ac-9a1139d56716
# .Added 33 chunks
#
# Parsing: A scoping review of wildfire smoke risk communications issues, gaps, and recommendations
# Started parsing the file under job_id cc5900a4-67fe-4e54-82e7-7a768f5da7eb
# .Added 50 chunks
#
# Parsing: Wildfire Exposure and Respiratory Health- A Comprehensive Review of Emerging Evidence
# Started parsing the file under job_id 08f9c033-a02a-4ce1-b334-26864a102c88
# .Added 19 chunks
#
# Parsing: Heatwaves and wildfires suffocate our healthy start to life- time to assess impact and take action
# Started parsing the file under job_id 328a7249-c320-446b-8c89-75372e473eef
# Added 19 chunks
#
# Parsing: Public health applications of historical smoke forecasts- An evaluation of archived BlueSky data for the coterminous United States, 2015-2018
# Started parsing the file under job_id 57367f9e-8f65-494e-a955-7989b245c63d
# .Added 16 chunks
#
# Parsing: Trends and Gaps in Climate Change and Health Research in the Republic of Korea
# Started parsing the file under job_id bfa39599-14d0-4bc7-b3c3-0b0e79f77e4b
# Added 24 chunks
#
# Parsing: Machine learning-enabled regional multi-hazards risk assessment considering social vulnerability
# Started parsing the file under job_id 7f21900c-6123-45c8-b476-56d24d1a281d
# Added 21 chunks
#
# Parsing: Comprehensive Care for Wildfire Survivors in Los Angeles, 2025
# Started parsing the file under job_id d8fd7d18-26c5-46e9-926a-42eb9f308e88
# Added 3 chunks
#
# Parsing: Stressors for farmworker parents during wildfire season
# Started parsing the file under job_id d5b081ce-ffa0-4acf-8285-bdbad0ea5888
# Added 24 chunks
#
# Parsing: Monitoring Public Health During the 2023 Maui Wildfire Using Google Search Trends
# Started parsing the file under job_id b093636b-fcc9-450a-b2ad-4a5328d68f04
# Added 12 chunks
#
# Parsing: Emergency Medical Services response to wildfires from a public health perspective- A systematic review
# Started parsing the file under job_id 65944197-22f2-4edf-8a53-2eead6b8ccce
# .Added 15 chunks
#
# Parsing: Effects of Wildfire Events on California Radiation Oncology Clinics and Patients
# Started parsing the file under job_id a32ae2b8-84a3-4443-80c9-49ceff895489
# Added 20 chunks
#
# Parsing: Assessment of Regional Nursing Home Preparedness for and Regulatory Responsiveness to Wildfire Risk in the Western US
# Started parsing the file under job_id 1f9c8e07-742d-4abe-b70c-62588788cc92
# .Added 20 chunks
#
# Parsing: GeoHealth - 2021 - Johnson - Uncertainty in Health Impact Assessments of Smoke From a Wildfire Event
# Started parsing the file under job_id 0c1f5924-ac76-40ea-8845-11978273e610
# .Added 31 chunks
#
# Parsing: Health equity in the wake of disasters and extreme weather- evidence from an umbrella review
# Started parsing the file under job_id 26c5eca9-767e-47c2-839b-8e2c058f5554
# .Added 20 chunks
#
# Parsing: Chronic Mental Health Sequelae of Climate Change Extremes A Case Study of the Deadliest Californian Wildfire
# Started parsing the file under job_id e18ba535-70fd-4d82-a604-0a08b3ad6e92
# .Added 31 chunks
#
# Parsing: Health Planning   Management - 2024 - Zurynski - Bolstering health systems to cope with the impacts of climate change
# Started parsing the file under job_id a82c177b-3266-4b92-97ac-22030c77904e
# .Added 36 chunks
#
# Parsing: Participatory multi-criteria evaluation of landscape values to inform wildfire management
# Started parsing the file under job_id ce51276d-a593-4a7e-905c-7da820cf6a2e
# .Added 28 chunks
#
# Parsing: Role_of_Public_Health_in_Wildfire_Lessons_from_the
# Started parsing the file under job_id 1d2e331e-18d9-4a44-8c09-a6f4715c803c
# .Added 20 chunks
#
# Parsing: Socio-demographic and health vulnerability in prescribed-burn exposed versus unexposed counties near the National Forest System
# Started parsing the file under job_id 0fcec3bb-dea3-4d98-9156-6dbe2dc6a349
# .Added 32 chunks
#
# Parsing: Scaling Up- Citizen Science Engagement and Impacts Beyond the Individual
# Started parsing the file under job_id 67d04db5-77cb-42f6-8c36-047496f72f70
# .Added 22 chunks
#
# Parsing: münzel-et-al-2026-environmental-stressors-and-cardiovascular-health-acting-locally-for-global-impact-in-a-changing
# Started parsing the file under job_id aca5f580-73ff-46c1-8d45-a80b2b9d42a7
# Added 16 chunks
#
# Parsing: Responses to Wildfire and Prescribed Fire Smoke- A Survey of a Medically Vulnerable Adult Population in the Wildland-Urban Interface, Mariposa County, California.
# Started parsing the file under job_id f73c8f3b-02d3-45a6-a098-a42e5d6428d7
# ..Added 20 chunks
#
# Parsing: Climate Change And Its Impact On Asthma In South Africa.
# Started parsing the file under job_id 9667a023-c85d-4496-9119-7b132936f492
# Added 12 chunks
#
# Parsing: Engaging interested parties to optimize wildfire smoke communication in Canada challenges with initiating change
# Started parsing the file under job_id af55c602-f103-4161-8699-4046017f4843
# .Added 18 chunks
#
# Parsing: Impact of Natural Disasters on Health Outcomes and Cancer Among Older Adults.
# Started parsing the file under job_id 1b1ee6be-ceae-4e6e-afb2-1ec389fdade9
# Added 16 chunks
#
# Parsing: savich-et-al-2025-effects-of-wildfire-smoke-inhalation-on-respiratory-health
# Started parsing the file under job_id 4defd81c-381f-4b56-a2fc-b0ac8cf6f4c4
# .Added 26 chunks
#
# Parsing: Knowing Your Audience A Typology of Smoke Sense Participants to Inform Wildfire Smoke Health Risk Communication
# Started parsing the file under job_id 1ef2b059-df16-42b7-9ccd-74da80da00e6
# Added 21 chunks
#
# Parsing: Quantifying the premature mortality and economic loss from wildfire-induced PM(2.5) in the contiguous U.S
# Started parsing the file under job_id 118ccbd0-1fbf-4c0c-ae93-f45f4db61ccc
# Added 11 chunks
#
# Parsing: GeoHealth - 2019 - Rappold - Smoke Sense Initiative Leverages Citizen Science to Address the Growing Wildfire‐Related
# Started parsing the file under job_id 915f4fe7-3c92-4995-9c94-0a80042d9bf0
# .Added 28 chunks
#
# Parsing: Combating converging crises- The role of universities in global health, climate, and equity
# Started parsing the file under job_id 9ac060f0-5cfd-4ed4-bfb1-862e7b4cbfd6
# .Added 21 chunks
#
# Parsing: Wildfire impacts on education and healthcare Paradise, California, after the Camp Fire
# Started parsing the file under job_id 072519b8-f79e-45e6-b064-3a8a52fa8a06
# Added 39 chunks
#
# Parsing: Outbreak of Norovirus Illness Among Wildfire Evacuation Shelter Populations - Butte and Glenn Counties, California, November 2018
# Started parsing the file under job_id f9a30d61-c716-4374-b80f-b950cd8d3175
# Added 8 chunks
#
# Parsing: Risk Analysis - 2026 - Bodas - Municipal Risk Communication and Public Trust  Reducing Counterproductive Behaviors Across
# Started parsing the file under job_id 84a3aedb-4cf0-4386-a018-f1a12ae73f7e
# .Added 32 chunks
#
# Parsing: The 2024 South America ablaze- health impacts and policy imperatives for protecting population health in an era of wildfires
# Started parsing the file under job_id 63a04a93-fd47-4a34-a0a9-5197010c06d7
# Added 25 chunks
#
# Parsing: Changes in extreme events and the potential impacts on human health
# Started parsing the file under job_id 85bd7f0b-971c-435b-8aab-49428c2d20dd
# Added 49 chunks
#
# Parsing: A Literature Review on the Impact of Wildfires on Emergency Departments- Enhancing Disaster Preparedness.
# Started parsing the file under job_id 471a3240-9c92-4a87-96c0-9cf9fbf895fc
# Added 16 chunks
#
# Parsing: Housing Displacement, Employment Disruption, and Mental Health After the 2023 Maui Wildfires
# Started parsing the file under job_id cac12d7b-d6a6-47b2-828f-cbb2b4b8ec4c
# .Added 23 chunks
#
# Parsing: Improving Wildfire Readiness Among Patients With Chronic Obstructive Pulmonary Disease and Asthma- Applying a Population Health Approach to Climate Change
# Started parsing the file under job_id 0972f366-0351-4957-aa7b-e4e2530fb874
# Added 16 chunks
#
# Parsing: An Ecological Perspective on Living with Fire in Ponderosa Pine Forests of Oregon and Washington- Resistance, Gone but not Forgotten
# Started parsing the file under job_id 6f7e0e1d-3ffc-4e2b-98cb-4a7eaae970f5
# .Added 50 chunks
#
# Parsing: Clearing the air- evaluating institutions' social media health messaging on wildfire and smoke risks in the US Pacific Northwest
# Started parsing the file under job_id 1e54cccc-bd22-441a-8ef7-a5228abc397c
# .Added 33 chunks
#
# Parsing: Who Among the Elderly Is Most Vulnerable to Exposure to and Health Risks of Fine Particulate Matter From Wildfire Smoke?
# Started parsing the file under job_id dd1b1746-4b99-4196-8207-d289797dc8ef
# Added 12 chunks
#
# Parsing: Burning issues- trends in newspaper coverage of wildfire events and health.
# Started parsing the file under job_id ce1c2487-d7d3-42e8-a028-621ceecc6392
# Added 19 chunks
#
# Parsing: Learning from Wildfire Disaster Experience in California NICUs
# Started parsing the file under job_id 3adf40c5-c9d6-44fd-b847-81ef99d6d511
# Added 13 chunks
#
# Building index over 1392 total chunks...
# Saving index to Drive...
# Index saved to /content/drive/MyDrive/research_papers/index

# %%
query_engine = combined_index.as_query_engine(
    similarity_top_k=10,
    verbose=True
)

print("Query engine ready")
# Out:
# Query engine ready

# %%
response =  query_engine.query(("What kinds of physical and mental health impacts are associated with wildfire exposure?"))
print(str(response))
# Out:
# Exposure to wildfires can have significant physical and mental health impacts, particularly due to the direct effects of exposure to wildfire smoke on cardio-respiratory health, psychological stress, and the use of alcohol and drugs. Individuals at increased risk of depression, anxiety, PTSD, insomnia, and substance abuse may experience these impacts, especially 12 to 14 months after the event. In terms of physical health, individuals who are directly exposed to wildfires may experience short- and long-term physical health consequences, such as injuries from the fire itself or from the resulting debris and ash, as well as cardiovascular and respiratory health conditions. In terms of mental health, exposure to wildfires has been linked to a range of negative outcomes, including increased symptoms of post-traumatic stress disorder (PTSD), depression, and anxiety disorders, which can be particularly pronounced in individuals who experience high levels of stress and trauma in the aftermath of a wildfire, such as those who have lost their homes or experienced significant property damage. Furthermore, the degree of exposure to the wildfire, including proximity to the fire and the extent of household damage or physical injury, has been shown to be associated with increased symptoms of PTSD, depression, and anxiety disorders. Additionally, the impact of wildfires on maternal health and the health of the offspring is a critical area of concern, as women's ability to thermoregulate is altered during pregnancy, and extreme heat and wildfires can have a significant impact on maternal health and the health of the offspring.

# %%
response = query_engine.query("How does wildfire smoke, especially PM2.5, affect respiratory and cardiovascular health?")
print(str(response))
# Out:
# **Rewrite**
#
# Exposure to wildfire smoke, particularly fine particulate matter (PM2.5), has been linked to increased risks of respiratory and cardiovascular diseases in vulnerable populations, including those with preexisting lung and airway diseases. The toxicological impact of wildfire PM2.5 is heightened due to its high concentrations of oxidative and proinflammatory components, such as oxygenated polycyclic aromatic hydrocarbons (PAHs) and quinones. These components can cause significant damage to lung cells, facilitating the development or worsening of respiratory infections and airway diseases, including asthma and chronic obstructive pulmonary disease (COPD).
#
# The inhalation of wildfire-related pollutants can also lead to increased oxidative stress and inflammation, which can contribute to cardiovascular disease, particularly in individuals with preexisting cardiovascular conditions. The finer particles in wildfire smoke can be transported long distances, increasing the potential for adverse health effects across broader regions. Studies have demonstrated that exposure to wildfire smoke raises the risk of mortality from respiratory illnesses, with greater exposure to wildfire-derived PM2.5 correlating with increased risk of all-cause and respiratory-specific mortality. Additionally, research suggests that wildfire smoke may exert greater toxicity than ambient PM2.5 from nonwildfire sources, highlighting the unique chemical composition and biological reactivity of wildfire emissions.
#
# Furthermore, exposure to wildfire smoke has been identified as a crucial environmental factor contributing to both the progression and exacerbation of COPD, a highly prevalent respiratory disorder that significantly increases healthcare utilization. The exposure to wildfire smoke exacerbates COPD by inhibiting autophagic flux and compromising airway epithelial barrier integrity, resulting in heightened inflammation and increased epithelial vulnerability.

# %%
response = query_engine.query("What kinds of mental health support might people need after wildfires?")
print(str(response))
# Out:
# **Rewrite**
#
# After experiencing a traumatic event like a wildfire, individuals may require various forms of mental health support to cope with their emotions and adjust to the new circumstances. This support can include counseling or therapy to process their feelings and develop coping strategies, as well as access to medication to manage symptoms of anxiety or depression.
#
# In addition to individual support, people may also benefit from group-based interventions that foster a sense of community and social connection. Research suggests that having stronger social group connections before a disaster can help reduce distress and enable resilience in the aftermath. This can involve joining support groups or participating in community-based activities that promote a sense of belonging and connection with others.
#
# It's also essential to acknowledge that people's needs may vary depending on their individual circumstances, such as the severity of their exposure to the wildfire, their pre-existing mental health conditions, and their social support networks. A comprehensive approach to mental health support should consider these factors and provide tailored support to meet the unique needs of each individual.
#
# Furthermore, studies have shown that pre-disaster social group connections can provide a foundation for mental health recovery after a disaster. This includes social identification with one's community, continuity of existing social identities, and development of new social identities. Therefore, mental health support should also focus on promoting and strengthening social connections, which can help individuals rebuild their lives and recover from the trauma of a wildfire.
#
# In the context of climate-related extreme events, such as wildfires, it's crucial to consider the long-term mental health impacts and provide ongoing support to individuals affected. This can involve regular check-ins with mental health professionals, access to community resources, and opportunities for social connection and community engagement. By taking a proactive and comprehensive approach to mental health support, we can help individuals and communities recover from the trauma of a wildfire and build resilience for future disasters.
#
# The research on this topic, as seen in studies such as those by Bryant et al. (2021) and Macleod et al. (2023), highlights the importance of social connections and community support in promoting mental health recovery after a disaster. Additionally, the work of Norris et al. (2002) and Weber et al. (2020) emphasizes the need for a comprehensive approach to mental health support that considers individual circumstances and provides tailored support to meet unique needs.

# %%
response = query_engine.query("How should public health agencies communicate wildfire smoke risks to different communities?")
print(str(response))
# Out:
# **Rewrite**
#
# To effectively communicate wildfire smoke risks to different communities, public health agencies should adopt a comprehensive approach that incorporates various communication channels and strategies, particularly at the community level, to advance organizational efforts in the area by leveraging digital tools and resources regarding smoke. This includes utilizing traditional sources such as TV and radio, as well as non-traditional platforms like social media and digital information, to increase awareness of connections between wildland fire, smoke, and health. Messages should be clear, current, and actionable, with a focus on providing specific actions for minimizing wildfire smoke exposure, and should be tailored to local contexts and incorporate local places of gathering, such as community centers and trusted organizations, to build trust among residents and facilitate effective risk communication. Additionally, agencies should consider the unique needs and concerns of vulnerable populations, such as Indigenous populations, and those with pre-existing medical conditions, and use research-based public messaging to assess need for low-literacy, non-English, and basic information to know about a particular wildfire respiratory risk. By doing so, they can ensure that their risk communication efforts are inclusive, effective, and ultimately help protect the health and well-being of all community members.

# %%
response = query_engine.query("What wildfire smoke communication barriers affect non-English-speaking families and other vulnerable groups?")
print(str(response))
# Out:
# **Rewrite**
#
# Language barriers pose a significant challenge for non-English-speaking families and other vulnerable groups in accessing and understanding health information about bushfire smoke. This can hinder their ability to protect themselves and their children from its detrimental effects. The lack of alignment of bushfire smoke risk communication materials with accepted health literacy principles, such as readability, accessibility, and actionability, can exacerbate these challenges. Furthermore, language barriers can also affect their ability to access official documents and social support, making it even more difficult for these groups to understand and respond to bushfire smoke risk communications.

# %%
response = query_engine.query("How can hospitals, neonatal intensive care units, and nursing homes prepare for wildfire smoke events or evacuations?")
print(str(response))
# Out:
# **Rewrite**
#
# To prepare for wildfire smoke events or evacuations, hospitals, neonatal intensive care units, and nursing homes should have a comprehensive disaster response plan in place, taking into account the unique challenges and risks associated with wildfires. This plan should include identifying potential risks and vulnerabilities, conducting regular drills and training exercises, and establishing clear communication protocols.
#
# It's essential to have a list of essential items and equipment, including medical supplies, medications, and personal protective equipment (PPE), readily available. This will enable staff to respond quickly and effectively in the event of an emergency, particularly in areas prone to wildfires like California, Oregon, and Southwest Washington.
#
# Developing a system for categorizing patients based on their level of acuity and medical needs can also help ensure that the most critical patients receive the necessary care and attention during an evacuation. This might involve using a color-coded system, such as pink, yellow, and green, to indicate the level of support required.
#
# Regular debriefing and review of past experiences, including the 2020 wildfires in California and the recent wildfires in Oregon and Southwest Washington, can also help identify areas for improvement and ensure that staff are prepared to respond to future disasters. This might involve conducting interviews with staff members, reviewing incident reports, and analyzing data to identify trends and patterns.
#
# In addition, having a plan for transporting patients, including identifying potential evacuation routes and securing transportation services, is crucial. This might involve working with local emergency management agencies, identifying alternative care facilities, and establishing protocols for transporting patients with specialized medical needs.
#
# The availability of specialized tools and equipment, such as bassinets, Med-Sleds, and transport isolettes, can also play a critical role in ensuring the safe evacuation of patients. Furthermore, having a system in place for documenting and tracking patient information, including medical records, medication lists, and contact information for family members, will enable staff to provide continuity of care and ensure that patients receive the necessary treatment and support during an evacuation.
#
# Experience and experience-based training, such as the TRAIN™ tool, can also be valuable resources for NICUs in preparing for evacuations. By having a comprehensive disaster response plan, conducting regular drills and training exercises, and establishing clear communication protocols, hospitals, neonatal intensive care units, and nursing homes can be better prepared to respond to wildfire smoke events or evacuations.

# %%
response = query_engine.query("How does wildfire smoke complicate childcare, work, and wellbeing for farmworker families?")
print(str(response))
# Out:
# **Rewrite**
#
# Wildfire smoke poses a significant threat to the wellbeing of farmworker families, particularly in terms of childcare, work, and overall health. The prolonged exposure to smoke can exacerbate respiratory diseases and impact the health and wellbeing of both parents and children. This can lead to increased stress levels, making it challenging for families to cope with the stress of smoke events.
#
# Farmworker parents often struggle to balance work and childcare responsibilities due to the lack of safe and attainable childcare options, as well as inconsistent resources provided by employers. When smoke infiltrates homes, it can create a stressful situation that affects daily lives, leading to increased anxiety and stress levels for both children and parents.
#
# The unpredictable worksite responses to smoke can also lead to increased smoke inhalation and respiratory rates, resulting in acute symptoms. Farmworker parents may feel unprepared to protect themselves and their families from smoke exposure, and may be concerned about their children's health and exposure to air pollutants, as well as their own mental wellbeing during smoke events.
#
# In this context, the lack of accessible and reliable childcare options can exacerbate the stress and anxiety experienced by farmworker families. Children may worry about the safety of their family and the potential for smoke to reach their home, leading to increased stress levels for both children and parents. The need for improved worksite environments, clear and consistent communication, and accessible resources is crucial to mitigate the impact of wildfire smoke on farmworker families.

# %%
response = query_engine.query("How can social vulnerability and public risk perceptions be incorporated into wildfire preparedness and planning?")
print(str(response))
# Out:
# **Rewrite**
#
# Incorporating social vulnerability and public risk perceptions into wildfire preparedness and planning involves acknowledging the intricate relationships between environmental risk, social values, and cultural influences. This requires recognizing that risk perceptions are shaped by individual experiences, social norms, and community values, which significantly influence behavioral outcomes, such as taking proactive steps to prepare for future wildfires.
#
# By fostering a culture of community engagement and participation, planners can create social spaces that allow citizens to share their knowledge, values, and preferences for effective land use management, ultimately leading to more effective disaster preparedness and community helping interventions. This can be achieved through early and ongoing community involvement in the planning process, which helps build trust and fosters a sense of ownership among community members.
#
# Moreover, planners should consider the role of subjective norms, such as descriptive norms, in shaping behavioral intentions and outcomes, particularly in the context of community helping behavior. By understanding how community members perceive and respond to risk, planners can develop targeted interventions that address specific social and cultural factors influencing risk perceptions and preparedness, ultimately leading to more effective community helping behavior.
#
# The findings on the importance of informal discussions, formal sources, and descriptive norms in shaping disaster preparedness and community helping behavior highlight the need for a nuanced understanding of the complex relationships between environmental risk, social values, and cultural influences. By adopting a reflexive and participatory approach, planners can develop more effective and inclusive strategies for managing wildfire risk and promoting community resilience, ultimately leading to more effective community helping behavior.

# %%
response = query_engine.query("What should public health agencies consider when using prescribed fire as a wildfire mitigation strategy?")
print(str(response))
# Out:
# **Rewrite**
#
# When using prescribed fire as a wildfire mitigation strategy, public health agencies should consider the complex interplay between prescribed fire smoke and community health, particularly among vulnerable populations. They should account for the potential health impacts of prescribed fire smoke, including the effects of lower exposure levels, and strive to minimize the impact on air quality as measured by fine particulate matter (PM2.5). Moreover, agencies should prioritize clear and consistent messaging, connecting people to resources, and flexibility in resource allocation to support community resilience during wildfire events. This includes providing timely information on wildfire smoke, using multiple channels, and non-internet dependent options to alleviate dissatisfaction with information received. Furthermore, agencies should engage the community and build confidence to foster health, social, and emotional resilience in populations facing wildland smoke challenges.

# %%
response = query_engine.query("How can citizen science, mobile apps, social media, and public messaging improve wildfire smoke awareness and protective action?")
print(str(response))
# Out:
# **Rewrite**
#
# Citizen science initiatives, mobile apps, social media, and public messaging can be crucial in enhancing wildfire smoke awareness and promoting protective action, particularly for vulnerable populations in risk communication. By harnessing these platforms, communities can be empowered to take an active role in monitoring and mitigating the effects of wildfire smoke. Mobile apps can provide individuals with real-time information on air quality, wildfire smoke levels, and health advisories, enabling people to make informed decisions about their daily activities and take necessary precautions to protect their health.
#
# Social media can be used to disseminate critical information, share personal experiences, and mobilize communities to take action, especially when messages are timely, practical, consistent, and provide details about short-term and long-term health effects. Public messaging campaigns can also be effective in raising awareness about the risks associated with wildfire smoke and promoting protective behaviors, particularly when they are non-alarming and scientifically grounded.
#
# Citizen science initiatives can engage communities in monitoring and reporting on wildfire smoke levels, providing valuable data that can inform public health decisions and policy development. The use of masks, air cleaners, and leaving the area can also be effective in reducing exposure to wildfire smoke. By working together, communities can build resilience and take proactive steps to mitigate the impacts of wildfire smoke, ultimately reducing the risks associated with wildfire smoke and promoting healthier, more resilient communities.
